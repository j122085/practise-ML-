# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.Chrome(executable_path='D:\Driver\chromedriver.exe')

# %%
browser.get('http://www.yahoo.com')
assert 'Yahoo' in browser.title
elem = browser.find_element_by_name('p')  # Find the search box
elem.send_keys('seleniumhq' + Keys.RETURN)

browser.quit()

# %%
#搜索example
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(executable_path='D:\Driver\chromedriver.exe')
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()

# %%
#確認網頁是否運行
import unittest
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

class PythonOrgSearch(unittest.TestCase):

    def setUp(self):
        self.driver = webdriver.Chrome(executable_path='D:\Driver\chromedriver.exe')

    def test_search_in_python_org(self):
        driver = self.driver
        driver.get("http://www.python.org")
        self.assertIn("Python", driver.title)
        elem = driver.find_element_by_name("q")
        elem.send_keys("pycon")
        elem.send_keys(Keys.RETURN)
        assert "No results found." not in driver.page_source


    def tearDown(self):
        self.driver.close()

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: C:\Users\andy (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\andy'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # 各種指向方法

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
driver =webdriver.Chrome(executable_path='D:\Driver\chromedriver.exe')

# %%
driver.get("http://am.wowprime.com/api/map")

# %%
#<input type="text" name="passwd" id="passwd-id" />

# %%
# btn104=driver.find_element(By.XPATH, '//button[text()="104工作資料點"]')
btn104 = driver.find_element_by_xpath('//button[text()="104工作資料點"]')

# %%
btn104.click()

# %%
addressInput = driver.find_element_by_id('address')

# %%
selectBigCity=driver.find_element_by_id("bigCity")

# %%
selectBigCity.send_keys("台中市")

# %%
driver.find_element_by_id("smallCity").send_keys("西區")

# %%
addressInput.clear()
addressInput.send_keys("國立台北科技大學")
# addressInput.send_keys(Keys.RETURN)
driver.find_element(By.XPATH,'//button[text()="提交"]').click()
time.sleep(2)

# %%
import time
xxx=driver.find_element_by_id("transit")
for i in xxx.text.split("\n"):
    driver.find_element_by_xpath('//option[text()="{}"]'.format(i)).click()
    time.sleep(0.3)

# %%
all_options = xxx.find_elements_by_tag_name("option")
for option in all_options:
#     print("Value is: %s" % option.get_attribute("value"))
    option.click()
    time.sleep(0.3)

# %%
from selenium.webdriver.support.ui import Select
select=Select(xxx)
all_options=select.options
for option in all_options:
#     print("Value is: %s" % option.get_attribute("value"))
    option.click()
    time.sleep(0.3)

# %% [markdown]
# # 將指向完畢的資料變成給beautifulsoup撈的資料

# %%
from bs4 import BeautifulSoup as bs
soup=bs(driver.page_source,"lxml")

# %%
x=soup.select_one("#address")
x
# Out:
# <input id="address" onsubmit="geocodeAddress()" type="textbox" value="台灣大道二段218號"/>

# %%
time.sleep(3)
x['value']
# Out:
# '台灣大道二段218號'

# %%
driver.get("http://www.google.com")

# %%
driver.get("http://am.wowprime.com/api/map")

# %%
driver.back()#上一頁

# %%
driver.forward()# 下一頁

# %%
driver.close()

# %% [markdown]
# # 取消選擇的方法
# deselect_by_index(index)
# deselect_by_value(value)
# deselect_by_visible_text(text)
# deselect_all()

# %% [markdown]
# # 遭做滑鼠的方法
# click(on_element=None) ——单击鼠标左键
#
# click_and_hold(on_element=None) ——点击鼠标左键，不松开
#
# context_click(on_element=None) ——点击鼠标右键
#
# double_click(on_element=None) ——双击鼠标左键
#
# drag_and_drop(source, target) ——拖拽到某个元素然后松开
#
# drag_and_drop_by_offset(source, xoffset, yoffset) ——拖拽到某个坐标然后松开
#
# key_down(value, element=None) ——按下某个键盘上的键
#
# key_up(value, element=None) ——松开某个键
#
# move_by_offset(xoffset, yoffset) ——鼠标从当前位置移动到某个坐标
#
# move_to_element(to_element) ——鼠标移动到某个元素
#
# move_to_element_with_offset(to_element, xoffset, yoffset) ——移动到距某个元素（左上角坐标）多少距离的位置
#
# perform() ——执行链中的所有动作
#
# release(on_element=None) ——在某个元素位置松开鼠标左键
#
# send_keys(*keys_to_send) ——发送某个键到当前焦点的元素
#
# send_keys_to_element(element, *keys_to_send) ——发送某个键到指定元素

# %%
# !pip install xl2dict
# Out:
# Collecting xl2dict
#   Downloading xl2dict-0.1.5.tar.gz
# Collecting future (from xl2dict)
#   Downloading future-0.16.0.tar.gz (824kB)
# Requirement already satisfied: openpyxl in d:\anaconda\lib\site-packages (from xl2dict)
# Requirement already satisfied: xlrd in d:\anaconda\lib\site-packages (from xl2dict)
# Requirement already satisfied: jdcal in d:\anaconda\lib\site-packages (from openpyxl->xl2dict)
# Requirement already satisfied: et_xmlfile in d:\anaconda\lib\site-packages (from openpyxl->xl2dict)
# Building wheels for collected packages: xl2dict, future
#   Running setup.py bdist_wheel for xl2dict: started
#   Running setup.py bdist_wheel for xl2dict: finished with status 'done'
#   Stored in directory: C:\Users\andy.yuan\AppData\Local\pip\Cache\wheels\82\b5\fd\a1ec15c8202b8a6582432633cf23d85287f8e74da0328b3a4f
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\andy.yuan\AppData\Local\pip\Cache\wheels\c2\50\7c\0d83b4baac4f63ff7a765bd16390d2ab43c93587fac9d6017a
# Successfully built xl2dict future
# Installing collected packages: future, xl2dict
# Successfully installed future-0.16.0 xl2dict-0.1.5

# %%
import xl2dict

# %%
myxlobject= xl2dict.XlToDict()

# %%
# myxlobject.convert_sheet_to_dict(file_path=r"D:\PythonCode\data\104_20180116.xlsx", sheet="First Sheet",
#                                  filter_variables_dict={"User Type" : "Admin", "Environment" : "Dev"})
myxlobject.convert_sheet_to_dict(file_path=r"D:\PythonCode\data\104_20180116.xlsx", sheet="First Sheet",
                                 filter_variables_dict={"bigadd" : "台北市"})
# Out:
# [{'': 0.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5e3a426d5a363f5631323a632c3e381d0624a44255a5c3e2121212163382b2625381j01',
#   'JOB': '飲料店早班計時人員(台北南陽店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南陽街15之7號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044311,
#   'LON': 121.516158,
#   'NAME': '水巷茶弄餐飲事業有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 1.0,
#   'APPEAR_DATE': '20180110',
#   'J': '614d47705d39425934353d6633313b1f23f734627376f42242424241f3c642928654j49',
#   'JOB': '請客樓餐廳計時服務員(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045031,
#   'LON': 121.522085,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 2.0,
#   'APPEAR_DATE': '20180109',
#   'J': '6866482a603c455c3738406932443e23168504a2b606244272727276b3f312c2b826j56',
#   'JOB': '飲料店早班正職人員(台北南陽店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南陽街15之7號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044311,
#   'LON': 121.516158,
#   'NAME': '水巷茶弄餐飲事業有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 3.0,
#   'APPEAR_DATE': '20171214',
#   'J': '4c4a446b5e363f5631323a634e2e36620406042253c5c3e2121212166382b2625381j99',
#   'JOB': '麵包製作正職社員(台大店)',
#   'JOBCAT_DESCRIPT': '麵包師',
#   'JOB_ADDRESS': '中山南路7號(台大醫院B1)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.040654,
#   'LON': 121.518549,
#   'NAME': '台灣山崎股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 4.0,
#   'APPEAR_DATE': '20180112',
#   'J': '544e48282f62426b346c3f6738423a66454744629292929254246542240j52',
#   'JOB': '中餐助廚-台北凱撒',
#   'JOBCAT_DESCRIPT': '飯店工作人員',
#   'JOB_ADDRESS': '忠孝西路一段38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046243,
#   'LON': 121.516461,
#   'NAME': '台北凱撒大飯店 _國裕開發股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 5.0,
#   'APPEAR_DATE': '20180112',
#   'J': '394b44295f37405732333b64393f37608634b45275b5d3f222222221d3b3c2726472j57',
#   'JOB': '起薪140元起【貳樓餐廳Second Floor Cafe-公館店】 服務生/外場 早晚班兼職',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '羅斯福路三段316巷9弄7號 貳樓餐廳 公館店',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0157397,
#   'LON': 121.531688,
#   'NAME': '貳樓餐飲有限公司',
#   'SAL_MONTH_HIGH': 26400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 6.0,
#   'APPEAR_DATE': '20180109',
#   'J': '50524a733c4e475e3d3a426b5e363e23148524b73404e46292929292840592e2d008j48',
#   'JOB': '晚班工讀生(拿坡里-台北市-南昌店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路一段151號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.029398,
#   'LON': 121.518736,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 7.0,
#   'APPEAR_DATE': '20180115',
#   'J': '58424b743c4e475e393a426b565c3f24262684a76446446292929292540592e2d008j56',
#   'JOB': '32.VIP會所-兼職服務人員【任職滿6個月可領取留任獎金10000元】',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中華路一段55號12樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042634,
#   'LON': 121.508778,
#   'NAME': '錢櫃企業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 8.0,
#   'APPEAR_DATE': '20180109',
#   'J': '4f4d466f3749425934353d662f413b208654d47285d5f4124242424693c642928654j02',
#   'JOB': '飲料店早班吧台工作人員(台北南陽店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南陽街15之7號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044311,
#   'LON': 121.516158,
#   'NAME': '水巷茶弄餐飲事業有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 9.0,
#   'APPEAR_DATE': '20180109',
#   'J': '50424c743c4e475e3d3a426b5e363e23148524b73404e46292929296b40592e2d008j48',
#   'JOB': '門市儲備幹部(三商巧福-台北市-信陽店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '信陽街16號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044568,
#   'LON': 121.515719,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 10.0,
#   'APPEAR_DATE': '20180109',
#   'J': '4e404a723a4c455c3b3840695c343c219465049713e4c44272727276b3f312c2b826j01',
#   'JOB': '門市儲備幹部(三商巧福-台北市-重南二店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '重慶南路一段11號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046123,
#   'LON': 121.513373,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 11.0,
#   'APPEAR_DATE': '20180109',
#   'J': '476345703749425938353d665931391e1434d466e3b494124242424243c642928654j55',
#   'JOB': '早班工讀生(福勝亭-台北市-站前店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '許昌街30號B1',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0454537,
#   'LON': 121.5158508,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 12.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4c4e4872384a435a35363e6734323c2084074472838704325252525213d552a29745j99',
#   'JOB': '安東廳計時服務員(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 13.0,
#   'APPEAR_DATE': '20180114',
#   'J': '66784a2c3c4e475e393a426b486c3f20862424b2d3c7447292929292540592e2d008j54',
#   'JOB': '兼職或工讀 服務人員-777咖啡',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '市民大道一段100號地下街美食區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.048704,
#   'LON': 121.515045,
#   'NAME': '七七七咖啡有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 14.0,
#   'APPEAR_DATE': '20180114',
#   'J': '617345273749425934353d6643673a1b85d3d4628376f4224242424203c642928654j49',
#   'JOB': '工讀生-777咖啡',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '市民大道一段100號地下街美食區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.048704,
#   'LON': 121.515045,
#   'NAME': '七七七咖啡有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 15.0,
#   'APPEAR_DATE': '20180110',
#   'J': '476346293749425934353d6633313b1f23f734627376f4224242424203c642928654j55',
#   'JOB': '宴會廳PT(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 16.0,
#   'APPEAR_DATE': '20180114',
#   'J': '4464472b384a435a35363e6744683b1c95e3e4729387043252525256a3d552a29745j52',
#   'JOB': 'Maid服務人員-Maiden Diner夢幻餐車女僕主題餐廳',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '市民大道一段100號地下街美食區11室',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0499092455,
#   'LON': 121.511182619,
#   'NAME': '七七七咖啡有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 17.0,
#   'APPEAR_DATE': '20180109',
#   'J': '4262452a3648415833343c655066391c93a724429585e4023232323203c2d2827563j50',
#   'JOB': '幾分甜 微風站前店-計時人員 時薪133-140',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '台北車站微風廣場',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '藍海國際餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 18.0,
#   'APPEAR_DATE': '20180111',
#   'J': '603c44272d3a406932343e6536403a1c93a724427272727273f44342260j48',
#   'JOB': '【天成飯店集團-台北天成】餐飲服務員(兼職)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段43號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046207,
#   'LON': 121.518174,
#   'NAME': '天成飯店股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 19.0,
#   'APPEAR_DATE': '20180102',
#   'J': '43414b2b3f4d465d3839416a47353d67557674a2e5d634528282828243f682d2c917j51',
#   'JOB': '和平公園 加州風洋食館 Skylark-內外場計時人員',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '懷寧街90號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042781,
#   'LON': 121.513943,
#   'NAME': 'Skylark加州風洋食館/古拉爵_雲雀國際股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 20.0,
#   'APPEAR_DATE': '20180110',
#   'J': '464c46273a48415833343c654240381a7644c45275c484023232323203c2d2827563j54',
#   'JOB': '(喫茶趣衡陽店)月薪人員-外場.吧檯',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '衡陽路62號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042156,
#   'LON': 121.5118,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 24000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 21.0,
#   'APPEAR_DATE': '20180115',
#   'J': '3b3941234b6b3d5530313962333d3518637394328555b3d202020201e373a2524290j98',
#   'JOB': '勝博殿內/外場兼職人員[站前店]',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段66號12樓[新光三越百貨內]',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046139,
#   'LON': 121.515241,
#   'NAME': '勝博殿_勝成餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 25600.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 22.0,
#   'APPEAR_DATE': '20171227',
#   'J': '53414b743b3d465d3839416a3b6b3d23169514a2d4f4d45282828286d3f682d2c917j51',
#   'JOB': '上海點心助手',
#   'JOBCAT_DESCRIPT': '中餐廚師',
#   'JOB_ADDRESS': '羅斯福路二段14號1樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.028418,
#   'LON': 121.521072,
#   'NAME': '蘇杭餐飲集團_蘇杭小館',
#   'SAL_MONTH_HIGH': 39000.0,
#   'SAL_MONTH_LOW': 33000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 23.0,
#   'APPEAR_DATE': '20180102',
#   'J': '58684a2c3c3e475e393a426b48363e68658684b2f5e6446292929292940592e2d008j56',
#   'JOB': '寶慶遠百店 加州風洋食館 Skylark-內外場計時兼職人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '寶慶路32號一樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.041473,
#   'LON': 121.50926,
#   'NAME': 'Skylark加州風洋食館/古拉爵_雲雀國際股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 24.0,
#   'APPEAR_DATE': '20171230',
#   'J': '423c44283e38415833343c653230386423a72442b425e4023232323653c2d2827563j50',
#   'JOB': '麵包製作人員(早班計時)(站前店)',
#   'JOBCAT_DESCRIPT': '麵包師',
#   'JOB_ADDRESS': '忠孝西路1段66號B2(新光三越-站前店DONQ麵包)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046245,
#   'LON': 121.5152825,
#   'NAME': '東客股份有限公司',
#   'SAL_MONTH_HIGH': 24800.0,
#   'SAL_MONTH_LOW': 24800.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 25.0,
#   'APPEAR_DATE': '20180110',
#   'J': '417144293d37405732333b64312f391d03d714425356d4022222222213b3c2726472j49',
#   'JOB': '請客樓餐廳-領檯、服務員 (台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045031,
#   'LON': 121.522085,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 26.0,
#   'APPEAR_DATE': '20180115',
#   'J': '54684a73483e475e393a426b565c3f24262684a76446446292929292840592e2d008j52',
#   'JOB': '10.北新館-正職服務人員【任職滿6個月可領取留任獎金18000元】',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '中華路一段55號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042634,
#   'LON': 121.508778,
#   'NAME': '錢櫃企業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 27.0,
#   'APPEAR_DATE': '20180110',
#   'J': '3f7346294339425934353d664341391b8654d46285d494124242424203c642928654j02',
#   'JOB': '專櫃吧台正職人員 天仁茗茶 (微風台北車站專櫃 2樓)',
#   'JOBCAT_DESCRIPT': '調酒師／吧台人員',
#   'JOB_ADDRESS': '北平西路3號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.04734,
#   'LON': 121.515575,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 28.0,
#   'APPEAR_DATE': '20180111',
#   'J': '5741492f473d465d3839416a475b3d2084f414a2e5d6345282828286b3f682d2c917j55',
#   'JOB': '西餐廳-工讀生(早班兼職)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中華路二段1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.02457,
#   'LON': 121.511757,
#   'NAME': '台北花園大酒店股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 29.0,
#   'APPEAR_DATE': '20180110',
#   'J': '5a4a442940363f5631323a63302e381c93c704324346c3f212121211e382b2625381j97',
#   'JOB': '桃山餐廳(日式料理)-NO.3 (台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045031,
#   'LON': 121.522085,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 30.0,
#   'APPEAR_DATE': '20180116',
#   'J': '67654729393b445b36373f6845333c2085f4f4871514b4326262626683e402b2a735j55',
#   'JOB': '伯朗咖啡館 長期計時人員 (站前店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '北平西路3號2樓 (台北火車站2樓)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0479239,
#   'LON': 121.517081,
#   'NAME': '伯朗咖啡股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 31.0,
#   'APPEAR_DATE': '20180116',
#   'J': '46404a2f3e3c455c3738406946343d21960504972524c4427272727273f312c2b826j54',
#   'JOB': '伯朗咖啡館 長期計時人員 (延平店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '延平南路127號(文化大學大新館)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.038416,
#   'LON': 121.508668,
#   'NAME': '伯朗咖啡股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 32.0,
#   'APPEAR_DATE': '20180116',
#   'J': '46504a2c6472445c3738406946343d2316466482f46624427272727273f312c2b826j54',
#   'JOB': '摩斯台醫店(053mos)-兼職 /計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中山南路7號地下一層',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0402323,
#   'LON': 121.5179104,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 33.0,
#   'APPEAR_DATE': '20180116',
#   'J': '4c524c2e6674465e393a426b48363f25366684a31486446292929296b40592e2d008j99',
#   'JOB': '摩斯重慶南路店(112mos)-兼職 /計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '重慶南路一段125號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042109,
#   'LON': 121.513341,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 34.0,
#   'APPEAR_DATE': '20180116',
#   'J': '4e7649733e3c455c3738406946343d2316466482f466244272727276b3f312c2b826j01',
#   'JOB': '摩斯捷運店(049mos)-兼職 /計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段49號B1(誠品商場)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046374,
#   'LON': 121.517896,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 35.0,
#   'APPEAR_DATE': '20180116',
#   'J': '4b7346703b39425934353d6643313a2086163452c435f4124242424693c642928654j98',
#   'JOB': '摩斯南昌店(106mos)-兼職 /計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '臺北市南昌路一段44號．1.2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 36.0,
#   'APPEAR_DATE': '20180116',
#   'J': '4f49426a43353e55303139623f2d361c95d5f41283f5b3d202020201d373a2524290j02',
#   'JOB': '摩斯公園店(067mos)-兼職 /計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '公園路38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0438459,
#   'LON': 121.516667,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 37.0,
#   'APPEAR_DATE': '20180109',
#   'J': '43414b303f4d465d3c39416a5d353d22047514a723f4d4528282828283f682d2c917j51',
#   'JOB': '早晚班工讀生(三商巧福-台北市-重南二店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '重慶南路一段11號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046123,
#   'LON': 121.513373,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 38.0,
#   'APPEAR_DATE': '20180109',
#   'J': '474d466e3f49425934353d665557392084373452c435f4124242424673c642928654j55',
#   'JOB': '(台北)古亭店_內外場兼職人員-時薪$150起',
#   'JOBCAT_DESCRIPT': '西餐廚師',
#   'JOB_ADDRESS': '羅斯福路二段60號(古亭站7號出口)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0275779,
#   'LON': 121.521753,
#   'NAME': 'TGI Fridays Taiwan_星期五股份有限公司',
#   'SAL_MONTH_HIGH': 29600.0,
#   'SAL_MONTH_LOW': 24000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 39.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4c4e486f404a435a35363e6734323c2084074472838704325252525693d552a29745j99',
#   'JOB': '辰園餐廳PT(台北喜來登飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 40.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4a4c466d3e48415833343c6532303a1e13e724526366e41232323231e3c2d2827563j97',
#   'JOB': '泰式餐廳 PT工讀(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 41.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4b49436a3b453e55303139623f3d351756149422459453d2020202064373a2524290j98',
#   'JOB': '(喫茶趣衡陽店)時薪人員-外場.吧檯',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '衡陽路62號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042156,
#   'LON': 121.5118,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 42.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4e50482a424c455c3738406946443c1e16850492b604c4427272727693f312c2b826j01',
#   'JOB': '(喫茶趣衡陽店)月薪人員-外場.吧檯',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '衡陽路62號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042156,
#   'LON': 121.5118,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 43.0,
#   'APPEAR_DATE': '20180109',
#   'J': '4f4d476e4349425934353d6659313b1f24f634570435f4124242424243c642928654j02',
#   'JOB': '【台北車站微風】儲備幹部-月薪28,000起(咖啡廳外場-無經驗可)(外商公司Aunt Stella)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '台北車站微風2F 新咖啡廳 Aunt Stella Coffee詩特莉咖啡',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 0.0,
#   'LON': 0.0,
#   'NAME': 'Aunt Stella_詩特莉食品股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 44.0,
#   'APPEAR_DATE': '20180112',
#   'J': '40684a2d484e475e393a426b40463e6756a524c2e626446292929292440592e2d008j48',
#   'JOB': '起薪140元起【貳樓餐廳Second Floor Cafe-北車微風店】 廚房/內場 早晚班兼職',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '北平西路3號 台北火車站內微風廣場2F (南二門出口樓上) 貳樓餐廳 微風台北車站店',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0329636,
#   'LON': 121.5654268,
#   'NAME': '貳樓餐飲有限公司',
#   'SAL_MONTH_HIGH': 26400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 45.0,
#   'APPEAR_DATE': '20180112',
#   'J': '627042252b5e3e6730683b63343e3662050704225252525253d58586381j50',
#   'JOB': '宴會廳工讀生-台北凱撒',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046243,
#   'LON': 121.516461,
#   'NAME': '台北凱撒大飯店 _國裕開發股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 46.0,
#   'APPEAR_DATE': '20180110',
#   'J': '607649724a4c455c3738406936343e2204276492a3a724527272727253f312c2b826j48',
#   'JOB': '宴會廳-服務員(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '飯店工作人員',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 47.0,
#   'APPEAR_DATE': '20180112',
#   'J': '403a43252b5e3e6730683b63343e3662050704225252525673c322e6381j48',
#   'JOB': '餐務員/洗碗員Steward-台北凱撒',
#   'JOBCAT_DESCRIPT': '洗碗人員',
#   'JOB_ADDRESS': '忠孝西路一段38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046243,
#   'LON': 121.516461,
#   'NAME': '台北凱撒大飯店 _國裕開發股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 48.0,
#   'APPEAR_DATE': '20180110',
#   'J': '3d71446e4547405732333b64312f391d03d714425356d4022222222663b3c2726472j00',
#   'JOB': '比薩屋餐廳-服務員(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044946,
#   'LON': 121.522082,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 49.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5341492e4b4d465d3839416a33453f24269514b2c61634528282828273f682d2c917j51',
#   'JOB': '飲料店廚房準備人員(台北南陽店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南陽街15之7號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044311,
#   'LON': 121.516158,
#   'NAME': '水巷茶弄餐飲事業有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 50.0,
#   'APPEAR_DATE': '20180111',
#   'J': '5f3b44262c393f6831333d64353f391b839714326262626263d59592270j02',
#   'JOB': '【天成飯店集團-台北天成】餐飲部 西餐廳服務員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段43號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046207,
#   'LON': 121.518174,
#   'NAME': '天成飯店股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 51.0,
#   'APPEAR_DATE': '20180116',
#   'J': '5f4f492b454b445b36373f6845333c2085f4f4871514b43262626266a3e402b2a735j02',
#   'JOB': '伯朗咖啡館 長期計時人員 (臺大醫院店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '台北市中正區常徳街1號 (台大醫院西址舊院區大門入口右側)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.041417,
#   'LON': 121.517181,
#   'NAME': '伯朗咖啡股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 52.0,
#   'APPEAR_DATE': '20180116',
#   'J': '48424b75504e475e393a426b4c363e67562684a2c626446292929296e40592e2d008j56',
#   'JOB': '【樂田麵包】門市正職人員_南海門市',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '近捷運中正紀念堂站',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.091075,
#   'LON': 121.5598345,
#   'NAME': '薩摩亞商客來喜餐飲股份有限公司台灣分公司',
#   'SAL_MONTH_HIGH': 27000.0,
#   'SAL_MONTH_LOW': 25000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 53.0,
#   'APPEAR_DATE': '20180116',
#   'J': '5d4d452c3b49425934353d6643313a2086163452c435f4124242424683c642928654j00',
#   'JOB': '摩斯北投店(034mos)-兼職 / 計時人員及外送人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝東路一段178號1樓及B1',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.04389,
#   'LON': 121.526336,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 54.0,
#   'APPEAR_DATE': '20180115',
#   'J': '484e475e393a426b5636406844323c664543e482929292925415c362240j56',
#   'JOB': '門市儲備幹部(中正 / 萬華區)',
#   'JOBCAT_DESCRIPT': '儲備幹部',
#   'JOB_ADDRESS': '中正萬華區門市',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 0.0,
#   'LON': 0.0,
#   'NAME': '達美樂披薩股份有限公司',
#   'SAL_MONTH_HIGH': 40000.0,
#   'SAL_MONTH_LOW': 29000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 55.0,
#   'APPEAR_DATE': '20180111',
#   'J': '69514b613c3d456e37394124375b3e67561514b2c2c2c2c2b4539576d10j57',
#   'JOB': '肯德基-活力打工族-台北八德',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '八德路一段64號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0438758,
#   'LON': 121.5314242,
#   'NAME': '必勝客Pizza Hut/肯德基KFC_富利餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 56.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4d3b452541473f5732333b642d3f396205171436d4d473f222222221e3b3c2726472j00',
#   'JOB': '懷石創意冷盤料理師傅 (台北店)',
#   'JOBCAT_DESCRIPT': '日式廚師',
#   'JOB_ADDRESS': '北平東路14號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0460438,
#   'LON': 121.5244609,
#   'NAME': '鈺善閣．素．養生懷石_鈺善閣餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 57.0,
#   'APPEAR_DATE': '20180110',
#   'J': '3b63452a3b6f415934353d664367391d04f6346293f494124242424693c642928654j98',
#   'JOB': '漢口店-內場正職人員',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '漢口街19號B1',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045289,
#   'LON': 121.513984,
#   'NAME': 'CoCo壱番屋_台灣壹番屋股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 58.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4763452a3b6f415934353d664367391d04f6346293f494124242424243c642928654j55',
#   'JOB': '漢口店-日班工讀生',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '(依照公司規定分派)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': 'CoCo壱番屋_台灣壹番屋股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 59.0,
#   'APPEAR_DATE': '20171214',
#   'J': '4c3a446b3c6c3e5631323a634e2e36620406042253c5c3e2121212164382b2625381j99',
#   'JOB': '麵包製作早班計時人員(台大店)7:00-17:00',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '中山南路7號(台大醫院B1)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.040654,
#   'LON': 121.518549,
#   'NAME': '台灣山崎股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 60.0,
#   'APPEAR_DATE': '20180115',
#   'J': '62524c2d4474465e393a426b485c3f69758524b754c3e48292929292440592e2d008j50',
#   'JOB': '122.館前店-時薪服務人員【留任獎金10000元】',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '館前路34號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044667,
#   'LON': 121.51488,
#   'NAME': '好樂迪股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 61.0,
#   'APPEAR_DATE': '20180110',
#   'J': '3c4e462a4070425a35363e6744423a1c9664e47295e4a4225252525683d552a29745j99',
#   'JOB': '門市吧台人員 早班、晚班 正職及兼職or工讀  天仁茗茶 (公館門市)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '羅斯福路4段36號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.015347,
#   'LON': 121.533456,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 62.0,
#   'APPEAR_DATE': '20180102',
#   'J': '6977492e4373455d3839416a47353d67557674a2e5d6345282828286a3f682d2c917j57',
#   'JOB': '加州風洋食館 古拉爵 內外場營運儲備幹部-大台北地區 SKYLARK GRAZIE',
#   'JOBCAT_DESCRIPT': '儲備幹部',
#   'JOB_ADDRESS': '大台北地區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.091075,
#   'LON': 121.5598345,
#   'NAME': 'Skylark加州風洋食館/古拉爵_雲雀國際股份有限公司',
#   'SAL_MONTH_HIGH': 33000.0,
#   'SAL_MONTH_LOW': 28000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 63.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4b3d472a3f6f415934353d6633313b1f23f734627376f4224242424663c642928654j98',
#   'JOB': '助理調酒員(台北喜來登大飯店)',
#   'JOBCAT_DESCRIPT': '飯店工作人員',
#   'JOB_ADDRESS': '忠孝東路一段12號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045031,
#   'LON': 121.522085,
#   'NAME': '台北喜來登飯店_寒舍艾美酒店_礁溪寒沐酒店_寒舍餐旅管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 64.0,
#   'APPEAR_DATE': '20180104',
#   'J': '4363466f476f415934353d663331396533b73452c435f4124242424683c642928654j51',
#   'JOB': '門市人員(早班計時)(台北站前店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路1段66號B2(新光三越-站前店DONQ麵包)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046245,
#   'LON': 121.5152825,
#   'NAME': '東客股份有限公司',
#   'SAL_MONTH_HIGH': 24800.0,
#   'SAL_MONTH_LOW': 24800.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 65.0,
#   'APPEAR_DATE': '20180116',
#   'J': '444e462c4070425a35363e6744323b1f25e4e4770504a4225252525233d552a29745j52',
#   'JOB': '伯朗咖啡館 長期計時人員 (公館店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '羅斯福路三段236-1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.018347,
#   'LON': 121.530319,
#   'NAME': '伯朗咖啡股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 66.0,
#   'APPEAR_DATE': '20180116',
#   'J': '5c72442a4648405833343c654230391f26062442b425e4023232323233c2d2827563j99',
#   'JOB': '摩斯國家音樂廳店(122mos)-兼職人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中山南路21之1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.034876,
#   'LON': 121.518001,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 67.0,
#   'APPEAR_DATE': '20171201',
#   'J': '3e76482e3a62455c37384069366a3c6534a40492e3a724527272727273f312c2b826j01',
#   'JOB': '正職服務員【台北市-中正區】',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.029226,
#   'LON': 121.520445,
#   'NAME': '瓦城 /  非常泰  / 1010 湘  /  大心  /  十食湘_瓦城泰統股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 68.0,
#   'APPEAR_DATE': '20180104',
#   'J': '5e4e482c3860435a35363e6734423c6315e4e486f504a4225252525223d552a29745j01',
#   'JOB': 'PT時薪人員(台北市中正區)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '含大同區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0329636,
#   'LON': 121.5654268,
#   'NAME': 'Starbucks Coffee_統一星巴克股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 69.0,
#   'APPEAR_DATE': '20180111',
#   'J': '384a4229345c3f5631323a633c2e381b8404a426c40463f212121211e382b2625381j56',
#   'JOB': '百八魚場重慶店 外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '重慶南路一段113號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0426189,
#   'LON': 121.5133601,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 32000.0,
#   'SAL_MONTH_LOW': 28000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 70.0,
#   'APPEAR_DATE': '20180111',
#   'J': '44424b744064475e393a426b3c464068666784b31444e46292929296d40592e2d008j52',
#   'JOB': '廚房儲備幹部(中正區)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 71.0,
#   'APPEAR_DATE': '20180111',
#   'J': '413f48713d61445b36373f6839433d6536375482e414b43262626266a3e402b2a735j49',
#   'JOB': '儲備幹部(中正區)',
#   'JOBCAT_DESCRIPT': '飯店或餐廳主管',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 72.0,
#   'APPEAR_DATE': '20180111',
#   'J': '3e3c456e3a5e415833343c6536403a6206072452b3e484023232323673c2d2827563j01',
#   'JOB': '餐飲服務員(中正區)',
#   'JOBCAT_DESCRIPT': '工讀生',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 73.0,
#   'APPEAR_DATE': '20180111',
#   'J': '3c3a436c385c3f5631323a63343e386085e7043293c463e2121212166382b2625381j99',
#   'JOB': '廚助(中正區)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 74.0,
#   'APPEAR_DATE': '20180111',
#   'J': '503e47703c60435a35363e6738423c6426274472d404a4225252525223d552a29745j48',
#   'JOB': '服務員(兼職)',
#   'JOBCAT_DESCRIPT': '飯店工作人員',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 75.0,
#   'APPEAR_DATE': '20180110',
#   'J': '664e47703c60435a35363e6738323a1e15474472a383a4425252525223d552a29745j54',
#   'JOB': '【Sharetea 歇脚亭南陽店】早班長期工讀生',
#   'JOBCAT_DESCRIPT': '調酒師／吧台人員',
#   'JOB_ADDRESS': '南陽街11號1樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044996,
#   'LON': 121.516174,
#   'NAME': '歇脚亭_聯發國際餐飲事業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 76.0,
#   'APPEAR_DATE': '20180111',
#   'J': '5161446d395d405732333b64353f396195f71442a3d473f222222221f3b3c2726472j49',
#   'JOB': '廚師',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '衡陽路60號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421609,
#   'LON': 121.511897,
#   'NAME': 'Jolly Brewery + Restaurant_利誠餐飲有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 77.0,
#   'APPEAR_DATE': '20180115',
#   'J': '403e48703c60435a35363e6744583b653544e4771483a4425252525673d552a29745j48',
#   'JOB': '122.館前店-正職服務人員 【留任獎金18000元】',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '館前路34號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.044667,
#   'LON': 121.51488,
#   'NAME': '好樂迪股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 78.0,
#   'APPEAR_DATE': '20180112',
#   'J': '5e7446723c60435a35363e6748583a1c93c74462a483a4425252525213d552a29745j01',
#   'JOB': '【麻佬大 川味麻辣燙】台北微風北車店-兼職/工讀計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '北平西路3號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.047702,
#   'LON': 121.5173735,
#   'NAME': '王品餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 26400.0,
#   'SAL_MONTH_LOW': 24800.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 79.0,
#   'APPEAR_DATE': '20180115',
#   'J': '653d46273b5f425934353d664757391b83b73452947394324242424683c642928654j53',
#   'JOB': '酷必台北汀洲店-兼職/工讀計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '汀洲路三段198號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0123052,
#   'LON': 121.5353919,
#   'NAME': '王品餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 26720.0,
#   'SAL_MONTH_LOW': 25120.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 80.0,
#   'APPEAR_DATE': '20180115',
#   'J': '50524b2c4064475e393a426b445c3f24266784b2c4c3e48292929292940592e2d008j48',
#   'JOB': '【丹堤咖啡】計時人員-晚班(南昌店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路一段16號(近捷運中正紀念堂站)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0322332,
#   'LON': 121.5163293,
#   'NAME': 'Dante Coffee_丹堤咖啡食品股份有限公司',
#   'SAL_MONTH_HIGH': 24960.0,
#   'SAL_MONTH_LOW': 22720.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 81.0,
#   'APPEAR_DATE': '20180115',
#   'J': '65514a303f63465d3839416a4b353d6646167492b61634528282828263f682d2c917j53',
#   'JOB': '【樂田麵包】門市正職人員_衡陽門市',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '近捷運西門站4號出口',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.091075,
#   'LON': 121.5598345,
#   'NAME': '薩摩亞商客來喜餐飲股份有限公司台灣分公司',
#   'SAL_MONTH_HIGH': 27000.0,
#   'SAL_MONTH_LOW': 25000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 82.0,
#   'APPEAR_DATE': '20180114',
#   'J': '4d61446e4d6d4a2431433d1f312f37608393b436c35373f683d433b1e1e1e1e608473b613270j00',
#   'JOB': '小器食堂 - 外場正職服務人員（中山、華山店）',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '八德路一段一號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0441499,
#   'LON': 121.5294408,
#   'NAME': '小器生活創意股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 83.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4d3b442a3d5d405732333b644155371a7493b4428575d3f22222222673b3c2726472j00',
#   'JOB': 'Prime ONE牛排館廚房  Commis II',
#   'JOBCAT_DESCRIPT': '西餐廚師',
#   'JOB_ADDRESS': '中華路二段1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.028496,
#   'LON': 121.50539,
#   'NAME': '台北花園大酒店股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 84.0,
#   'APPEAR_DATE': '20171228',
#   'J': '48524c73624e475e393a426b345c3f68644524a2c444e46292929292440592e2d008j56',
#   'JOB': '餐飲時薪服務員(156台北濟南)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '濟南路二段66號1樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.040084,
#   'LON': 121.53254,
#   'NAME': '台灣麥當勞_和德昌股份有限公司',
#   'SAL_MONTH_HIGH': 261000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 85.0,
#   'APPEAR_DATE': '20171228',
#   'J': '4b514b72614d465d3839416a335b3e6754351492b434d45282828286d3f682d2c917j98',
#   'JOB': '餐飲時薪服務員(056林森二)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '林森南路1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0444909,
#   'LON': 121.523296,
#   'NAME': '台灣麥當勞_和德昌股份有限公司',
#   'SAL_MONTH_HIGH': 261000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 86.0,
#   'APPEAR_DATE': '20180110',
#   'J': '603c452a4a6e4b6a365a3c662e30386193a3c446d363840693e443c1f1f1f1f631484c5e3361j48',
#   'JOB': '門市餐飲服務人員(大台北區)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '台北市.新北市全區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.041961,
#   'LON': 121.52536,
#   'NAME': '八方雲集國際股份有限公司',
#   'SAL_MONTH_HIGH': 35000.0,
#   'SAL_MONTH_LOW': 34000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 87.0,
#   'APPEAR_DATE': '20180108',
#   'J': '5c3c46272d3a4069326a3d225030391e13e4c4527272727233e34382260j99',
#   'JOB': '西餐咖啡廳廚師',
#   'JOBCAT_DESCRIPT': '西餐廚師',
#   'JOB_ADDRESS': '汀州路三段184號B1(100)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.012619,
#   'LON': 121.534986,
#   'NAME': '金石堂圖書股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 88.0,
#   'APPEAR_DATE': '20180108',
#   'J': '593943242a373d662f673a1f4d2d361b83b494224242424203b31416391j57',
#   'JOB': '西餐咖啡廳外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '汀州路三段184號B1(100)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.012619,
#   'LON': 121.534986,
#   'NAME': '金石堂圖書股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 89.0,
#   'APPEAR_DATE': '20171229',
#   'J': '3e4c45295c48415833343c653a56391b8524c452a3e484023232323213c2d2827563j01',
#   'JOB': '晶湯匙泰式主題餐廳廚房助手(京站店)',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '北市承德路一段1號4樓(京站購物中心)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0493449,
#   'LON': 121.5168249,
#   'NAME': '晶湯匙泰式主題餐廳_共同存在國際餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 90.0,
#   'APPEAR_DATE': '20180114',
#   'J': '633b43295b47405732333b644165381975b3b4426356d4022222222663b3c2726472j51',
#   'JOB': '兼職或工讀 愛麗絲喫茶小鋪',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '市民大道一段100號地下街美食區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.048704,
#   'LON': 121.515045,
#   'NAME': '七七七咖啡有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 91.0,
#   'APPEAR_DATE': '20180110',
#   'J': '6840492f604c455c373840694a443e2084640492b5c6244272727276a3f312c2b826j56',
#   'JOB': '莫凡彼Café 兼職夥伴-台北誠品站前店',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段47號B1(台北車站K區B1)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.046392,
#   'LON': 121.5174304,
#   'NAME': '莫凡彼餐飲事業_百富通股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 92.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4e3c442b4a6e4b6c42343d682e30386193a3c446d363840693e443c1f1f1f1f1f2483c5e3361j01',
#   'JOB': '京站店 - 廚房助手全職/兼職 兼職時薪140元起',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '(依照公司規定分派)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': "Alleycat's Pizza_巷貓國際餐飲文化股份有限公司",
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 93.0,
#   'APPEAR_DATE': '20171227',
#   'J': '4e3c466f6048415833343c653666381e1644c45284a484023232323673c2d2827563j01',
#   'JOB': '上海點心師傅',
#   'JOBCAT_DESCRIPT': '中餐廚師',
#   'JOB_ADDRESS': '羅斯福路二段14號1樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.028418,
#   'LON': 121.521072,
#   'NAME': '蘇杭餐飲集團_蘇杭小館',
#   'SAL_MONTH_HIGH': 54000.0,
#   'SAL_MONTH_LOW': 42000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 94.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5650482a644c455c3b3840695c343c219465049713e4c44272727276b3f312c2b826j54',
#   'JOB': '外送工讀生(拿坡里-台北市-南昌店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路一段151號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.029398,
#   'LON': 121.518736,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 95.0,
#   'APPEAR_DATE': '20180109',
#   'J': '504a42245e463f5635323a63562e361b8404a436b38463e212121211d382b2625381j48',
#   'JOB': '櫃台客服人員(拿坡里-台北市-南昌店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路一段151號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.029398,
#   'LON': 121.518736,
#   'NAME': '三商行_三商巧福_拿坡里_福勝亭_鮮五丼_品川蘭_全家福_三商美福家具_三商投資控股股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 96.0,
#   'APPEAR_DATE': '20180111',
#   'J': '3d6143255f47405732333b643d55376315b4b446f41474022222222673b3c2726472j00',
#   'JOB': '急徵!!! 【野草居食屋】餐飲外場正職服務人員◆月休9-10天，年假12天◆',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '同安街28巷1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0248403,
#   'LON': 121.5216273,
#   'NAME': '云禾股份有限公司',
#   'SAL_MONTH_HIGH': 40000.0,
#   'SAL_MONTH_LOW': 28000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 97.0,
#   'APPEAR_DATE': '20180110',
#   'J': '6040492f4e724f6e3a5e406a32343c6533e4048713a3c446d424840232323232204a504c3725j48',
#   'JOB': '門市工讀生(大台北區)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '台北市.新北市',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.041961,
#   'LON': 121.52536,
#   'NAME': '八方雲集國際股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 98.0,
#   'APPEAR_DATE': '20180109',
#   'J': '3a4c452b4a6e4b225c443c1f2e30386193a3c446d363840693e443c1f1f1f1f619463c5e3361j97',
#   'JOB': '薪資(140元起)站前總店早班外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號B1(凱撒飯店美食廣場)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0462151,
#   'LON': 121.5165968,
#   'NAME': '太陽蕃茄拉麵_綠洲餐飲管理顧問有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 99.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5e74472d4c704d245e463e2130323a6313c3e466f383a426b40463e212121211c94974523543j01',
#   'JOB': '(薪資140元起)站前總店晚班外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號B1凱撒飯店',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0461769,
#   'LON': 121.5163956,
#   'NAME': '太陽蕃茄拉麵_綠洲餐飲管理顧問有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 100.0,
#   'APPEAR_DATE': '20180108',
#   'J': '5b4b45262c393f6831693c214f2f381d03d4b4426262626243f43592270j98',
#   'JOB': '西餐咖啡廳外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '汀州路三段184號B1(100)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.012619,
#   'LON': 121.534986,
#   'NAME': '金石堂圖書股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 101.0,
#   'APPEAR_DATE': '20180109',
#   'J': '4e404a2f4e724f266048402332343c6533e4048713a3c446d424840232323231f24a764c3725j01',
#   'JOB': '儲備幹部(薪30000~35000元起/面議)',
#   'JOBCAT_DESCRIPT': '日式廚師',
#   'JOB_ADDRESS': '忠孝西路一段38號B1凱撒飯店',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0461769,
#   'LON': 121.5163956,
#   'NAME': '太陽蕃茄拉麵_綠洲餐飲管理顧問有限公司',
#   'SAL_MONTH_HIGH': 35000.0,
#   'SAL_MONTH_LOW': 27000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 102.0,
#   'APPEAR_DATE': '20180112',
#   'J': '43774a2f654d465d3839416a3f453d66469514b2d61634528282828263f682d2c917j51',
#   'JOB': '起薪140元起【貳樓餐廳Second Floor Cafe-仁愛店】 廚房/內場 早晚班兼職',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '仁愛路二段108號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.037913,
#   'LON': 121.532453,
#   'NAME': '貳樓餐飲有限公司',
#   'SAL_MONTH_HIGH': 26400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 103.0,
#   'APPEAR_DATE': '20180109',
#   'J': '3b4d472c4b6f4c235d453d202f31396203b3d456e3739416a3f453d202020201c9483d5b3452j98',
#   'JOB': '(薪資165元起)站前總店外場早班計時社員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號(凱撒飯店B1)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0463455,
#   'LON': 121.5164302,
#   'NAME': '太陽蕃茄拉麵_綠洲餐飲管理顧問有限公司',
#   'SAL_MONTH_HIGH': 30400.0,
#   'SAL_MONTH_LOW': 26400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 104.0,
#   'APPEAR_DATE': '20180109',
#   'J': '3e504a2f4e724f266048402332343c6533e4048713a3c446d424840232323231f24b504c3725j01',
#   'JOB': '(薪資165元起)站前總店外場晚班計時社員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號(凱撒飯店B1)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0463455,
#   'LON': 121.5164302,
#   'NAME': '太陽蕃茄拉麵_綠洲餐飲管理顧問有限公司',
#   'SAL_MONTH_HIGH': 30400.0,
#   'SAL_MONTH_LOW': 26400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 105.0,
#   'APPEAR_DATE': '20171229',
#   'J': '424049723a62455c3738406936343c1f26850497452624427272727243f312c2b826j50',
#   'JOB': 'E客棧-中班服務人員(近台北捷運站)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南陽街7號2樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.045254,
#   'LON': 121.516185,
#   'NAME': 'E客棧_弘泉企業社',
#   'SAL_MONTH_HIGH': 35000.0,
#   'SAL_MONTH_LOW': 30000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 106.0,
#   'APPEAR_DATE': '20180111',
#   'J': '62424b753c64475e393a426b485c3e21950424b2f5e6446292929292540592e2d008j50',
#   'JOB': '宴會廳-服務員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中華路二段1號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0365909,
#   'LON': 121.5069002,
#   'NAME': '台北花園大酒店股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 107.0,
#   'APPEAR_DATE': '20180111',
#   'J': '5640482a3a62455c3738406942343e21946504872464c45272727276c3f312c2b826j54',
#   'JOB': '百八魚場重慶店 外場計時人員 (晚班)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '重慶南路一段113號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0426189,
#   'LON': 121.5133601,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 22400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 108.0,
#   'APPEAR_DATE': '20180110',
#   'J': '6a524a2e3c64475e393a426b48463e2086a524b2d624e46292929296e40592e2d008j97',
#   'JOB': '門市 吧台兼職or工讀人員 天仁茗茶(公館門市)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '羅斯福路4段36號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.015347,
#   'LON': 121.533456,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 109.0,
#   'APPEAR_DATE': '20180110',
#   'J': '4975482b3961445b36373f6845433b1d0674f482a5f4b4326262626263e402b2a735j57',
#   'JOB': '專櫃吧台 早.晚班兼職OR工讀人員  天仁茗茶(台北車站凱薩飯店專櫃)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.029226,
#   'LON': 121.520445,
#   'NAME': '天仁茶業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 110.0,
#   'APPEAR_DATE': '20180112',
#   'J': '627043294c5c3f5631323a6344543618638704226443640212121211d382b2625381j50',
#   'JOB': '王品集團-身心障礙人員徵才專區',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '王品餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 111.0,
#   'APPEAR_DATE': '20180109',
#   'J': '634f492b51714e25496d402639333b6423d3f4770393b436c41473f222222221d049654f3634j51',
#   'JOB': '【台北徐州館】中餐廚師',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '徐州路2號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.04074408050583,
#   'LON': 121.5208409196434,
#   'NAME': '儷宴會館_儷苑餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 112.0,
#   'APPEAR_DATE': '20171229',
#   'J': '613d466f595f425934353d663b573a1c9534d462b3f4941242424241f3c642928654j49',
#   'JOB': '晚班工讀生-晶湯匙泰式主題餐廳(京站店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '京站百貨4樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0316667,
#   'LON': 121.5163889,
#   'NAME': '晶湯匙泰式主題餐廳_共同存在國際餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 113.0,
#   'APPEAR_DATE': '20171229',
#   'J': '603c456e585e415833343c653a56391b8524c452a3e4840232323231f3c2d2827563j48',
#   'JOB': '長期工讀生-晶湯匙泰式主題餐廳外場兼職夥伴(京站店)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '承德路一段1號4樓(京站4樓)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0493618,
#   'LON': 121.5168299,
# ...
#   'JOB': '【和億北車店】內場廚房人員(晚班計時人員)',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '忠孝西路一段36號B1F',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0460066,
#   'LON': 121.5169442,
#   'NAME': '石研室股份有限公司',
#   'SAL_MONTH_HIGH': 23200.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 963.0,
#   'APPEAR_DATE': '20180112',
#   'J': '47414b2c6573506f6139426d47353d6643f4149723b3d456e434941242424242194b77493816j55',
#   'JOB': '[珍煮丹] 徵正職人員   近MRT中正紀念堂站   月休8天   2萬6起  CK',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '近中正紀念堂捷運站',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.032729,
#   'LON': 121.51827,
#   'NAME': '全球人事顧問股份有限公司',
#   'SAL_MONTH_HIGH': 32000.0,
#   'SAL_MONTH_LOW': 26000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 964.0,
#   'APPEAR_DATE': '20180115',
#   'J': '43514b2c657350274f49432337353d6643f4149723b3d456e434941242424242084b41493816j51',
#   'JOB': '高時薪【翡冷翠餐廳外場服務人員】歡迎有心並希望長期配合的二度就業人員與我們聯繫!',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '漢口街一段15號1樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0452754,
#   'LON': 121.514436,
#   'NAME': 'Hotel Relax旅樂序_大員昌實業有限公司',
#   'SAL_MONTH_HIGH': 25600.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 965.0,
#   'APPEAR_DATE': '20171215',
#   'J': '543e462a62704d6b4c363f2440323a6313c3e466f383a426b40463e212121216424974523543j52',
#   'JOB': '業界大手台湾進出！急徵正職門市人員！#2894',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '台灣英創管理顧問股份有限公司',
#   'SAL_MONTH_HIGH': 33000.0,
#   'SAL_MONTH_LOW': 31000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 966.0,
#   'APPEAR_DATE': '20180116',
#   'J': '494f472b4d4b455b36373f6839433d1d06765472e5f614326262626213e402b2a735j57',
#   'JOB': '有機門市廚房人員-福州門市(8:00~16:30)-固定休六日',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '棉花田生機園地股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 967.0,
#   'APPEAR_DATE': '20180116',
#   'J': '6573452c4b49435934353d66513139653436345283f5f4124242424233c642928654j53',
#   'JOB': '麵包製作計時人員(站前店)AM05:00~AM07:00',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '忠孝西路1段49號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0460841,
#   'LON': 121.518607,
#   'NAME': '台灣山崎股份有限公司',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 28800.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 968.0,
#   'APPEAR_DATE': '20180116',
#   'J': '524c46294a48425833343c654230391f26062442b425e4023232323683c2d2827563j50',
#   'JOB': '摩斯台大兒童醫院店(307mos)-兼職 / 計時人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中山南路8號B1F',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0441708,
#   'LON': 121.5187032,
#   'NAME': '摩斯漢堡_安心食品服務股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 969.0,
#   'APPEAR_DATE': '20180116',
#   'J': '4f41492f4f4d475d3839416a43353f69743414975474d46282828286c3f682d2c917j02',
#   'JOB': '快樂的計時夥伴-假日班(含國定假日)（台北火車站站前門市）',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '樂檸漢堡_樂檸鮮事股份有限公司',
#   'SAL_MONTH_HIGH': 22400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 970.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4d7143275747415732333b643d2f391c9414b436d41474022222222223b3c2726472j00',
#   'JOB': '膔柴小鮮燒肉古亭店 內場正職人員',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '南昌路二段216號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.023938,
#   'LON': 121.524422,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 36000.0,
#   'SAL_MONTH_LOW': 32000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 971.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4f6f412555453f55303139623b2d371a73f49416b3f453e202020201b373a2524290j02',
#   'JOB': '膔柴小鮮燒肉古亭店 外場服務人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路二段216號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.023938,
#   'LON': 121.524422,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 36000.0,
#   'SAL_MONTH_LOW': 32000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 972.0,
#   'APPEAR_DATE': '20180112',
#   'J': '493f492b5b4b455b36373f683d433b642674f492b5f614326262626683e402b2a735j57',
#   'JOB': '貳樓餐廳Second Floor Cafe(微風店)  服務生/外場  正職人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '台北市中正區羅斯福路三段316巷9弄7號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0157257,
#   'LON': 121.5315934,
#   'NAME': '貳樓餐飲有限公司',
#   'SAL_MONTH_HIGH': 28000.0,
#   'SAL_MONTH_LOW': 26000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 973.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5e3e482a5a4a445a35363e6738423c1f23c3e482d383a4425252525213d552a29745j01',
#   'JOB': '【集客人間茶館-杭州店】兼職廚房服務夥伴(晚班/假日班)',
#   'JOBCAT_DESCRIPT': '工讀生',
#   'JOB_ADDRESS': '杭州南路一段23號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0424074,
#   'LON': 121.5265416,
#   'NAME': '米塔集團:國際餐旅事業_二雪映月美食館',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 974.0,
#   'APPEAR_DATE': '20180109',
#   'J': '5939432555453f5530313962333d371a73739432833353f202020201d373a2524290j57',
#   'JOB': '【集客人間茶館-杭州店】兼職廚房服務夥伴(晚班/假日班)',
#   'JOBCAT_DESCRIPT': '工讀生',
#   'JOB_ADDRESS': '杭州南路一段23號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0424074,
#   'LON': 121.5265416,
#   'NAME': '米塔集團:國際餐旅事業_二雪映月美食館',
#   'SAL_MONTH_HIGH': 28800.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 975.0,
#   'APPEAR_DATE': '20180111',
#   'J': '3e4c45295848425833343c65504039631426245283e5e40232323231f3c2d2827563j01',
#   'JOB': '410同安店(早班08-16)青果人員',
#   'JOBCAT_DESCRIPT': '生鮮人員',
#   'JOB_ADDRESS': '同安街71號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0233279,
#   'LON': 121.521452,
#   'NAME': '(頂好Wellcome、JASONS Market Place) 惠康百貨股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 976.0,
#   'APPEAR_DATE': '20171227',
#   'J': '644c45295848425833343c6554303a1b85c72452836384223232323683c2d2827563j52',
#   'JOB': '台北研發助理',
#   'JOBCAT_DESCRIPT': '食品研發人員',
#   'JOB_ADDRESS': '仁愛路一段22號3樓',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0384804,
#   'LON': 121.5222678,
#   'NAME': '聯夏食品工業股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 977.0,
#   'APPEAR_DATE': '20180104',
#   'J': '624a43275646405631323a63303e385f25a4a446b4c463e2121212121382b2625381j50',
#   'JOB': 'FT門市正職人員(1/9 中正區聯合招募)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '包含中正區',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.035008,
#   'LON': 121.5210501,
#   'NAME': 'Starbucks Coffee_統一星巴克股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 978.0,
#   'APPEAR_DATE': '20180113',
#   'J': '6674472b5a4a445a35363e6752323c219623e477248604225252525243d552a29745j54',
#   'JOB': '【TOWN by Bryan Nagao】外場正職/儲備幹部 (薪優面議)',
#   'JOBCAT_DESCRIPT': '門市／店員／專櫃人員',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '威思創意股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 979.0,
#   'APPEAR_DATE': '20180111',
#   'J': '443a44275646405631323a63343e381b8383a44293436402121212166382b2625381j52',
#   'JOB': '★12月開幕★【神田燒肉丼-長安店】外場服務夥伴',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '中山區長安東路二段81號(新展門市預計12月開幕，近捷運松江南京站)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0485709,
#   'LON': 121.5345357,
#   'NAME': '米塔集團:國際餐旅事業_二雪映月美食館',
#   'SAL_MONTH_HIGH': 39000.0,
#   'SAL_MONTH_LOW': 27000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 980.0,
#   'APPEAR_DATE': '20180115',
#   'J': '5e7043292b383e6730583a63523e38197443a4325252525253c32586381j01',
#   'JOB': '百匯自助餐外場服務員(28)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 981.0,
#   'APPEAR_DATE': '20180115',
#   'J': '5e7043292b383e6730583a63523e38197443a4325252525253c422e6381j01',
#   'JOB': '百匯外場服務主任(28)',
#   'JOBCAT_DESCRIPT': '飯店或餐廳主管',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 982.0,
#   'APPEAR_DATE': '20180115',
#   'J': '5f71442a2c393f6831593b64533f391a7453b4426262626263d433b2270j02',
#   'JOB': '自助百匯中餐二廚(28)',
#   'JOBCAT_DESCRIPT': '中餐廚師',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 983.0,
#   'APPEAR_DATE': '20180115',
#   'J': '65774a30323f456e375f416a59453f2084b414a2c2c2c2c2c4439496d10j53',
#   'JOB': '百匯自助餐廚助(28)',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '延平南路110號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042631,
#   'LON': 121.509618,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 984.0,
#   'APPEAR_DATE': '20180115',
#   'J': '5d6f42282a373d662f573962513d3718643394224242424243c57316391j00',
#   'JOB': '百匯自助日式冷台二廚(28)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 985.0,
#   'APPEAR_DATE': '20180115',
#   'J': '6375482e303d436c355d3f6857433d1e1493f482a2a2a2a2a425d5d2230j51',
#   'JOB': '百匯自助西式冷台二廚(28)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 986.0,
#   'APPEAR_DATE': '20180115',
#   'J': '5e7043292b383e6730583a63523e38197443a4325252525253d68326381j01',
#   'JOB': '百匯自助日式烤/炸二廚(28)',
#   'JOBCAT_DESCRIPT': '其他類廚師',
#   'JOB_ADDRESS': '秀山街4號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.042787,
#   'LON': 121.509309,
#   'NAME': '海霸王集團_海霸王餐廳股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 987.0,
#   'APPEAR_DATE': '20180112',
#   'J': '3b6f426c59453f55303139624d3d361a73b394227595b3d202020201e373a2524290j98',
#   'JOB': '【微風台北車站】涓豆腐-正職餐飲人員',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '北平西路3號2樓(台鐵2樓東南側)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.047702,
#   'LON': 121.5173735,
#   'NAME': '涓豆腐/北村豆腐家/銅盤_豆府股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 988.0,
#   'APPEAR_DATE': '20180111',
#   'J': '52764973604c465c3738406942343e21946504872464c4527272727253f312c2b826j50',
#   'JOB': '膔柴小鮮燒肉古亭店 內場計時人員(早班)',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '南昌路二段216號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.023938,
#   'LON': 121.524422,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 24000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 989.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4e72456f5c48425833343c653e303a1d0424c446e42484123232323223c2d2827563j01',
#   'JOB': '膔柴小鮮燒肉古亭店 外場計時人員(早班)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '南昌路二段216號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.023938,
#   'LON': 121.524422,
#   'NAME': '百八魚場餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 24000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 990.0,
#   'APPEAR_DATE': '20180115',
#   'J': '4339436c59453f5530313962333d371a73739432833353f202020201c373a2524290j51',
#   'JOB': '★儲備幹部★【米塔義式廚房-凱撒店】外場儲備幹部(月薪30000起)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號b1(凱撒飯店,台北車站旁)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0462585,
#   'LON': 121.5164218,
#   'NAME': '米塔集團:國際餐旅事業_二雪映月美食館',
#   'SAL_MONTH_HIGH': 39000.0,
#   'SAL_MONTH_LOW': 30000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 991.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4e664874604c465c3738406932343c1f2426649725c4c4627272727263f312c2b826j01',
#   'JOB': '肯德基-全職人員-台北市(中正、中山、大同、萬華)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '、中山、大同、萬華區餐廳門市',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 0.0,
#   'LON': 0.0,
#   'NAME': '必勝客Pizza Hut/肯德基KFC_富利餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 26000.0,
#   'SAL_MONTH_LOW': 23000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 992.0,
#   'APPEAR_DATE': '20180111',
#   'J': '4870426e5a46405631323a632c2e361973c60436c5646402121212165382b2625381j56',
#   'JOB': '肯德基-活力打工族-台北市(中正、中山、大同、萬華)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '、中山、大同、萬華區餐廳門市',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 0.0,
#   'LON': 0.0,
#   'NAME': '必勝客Pizza Hut/肯德基KFC_富利餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 993.0,
#   'APPEAR_DATE': '20171213',
#   'J': '507042285e6c492348423c1f2c3e365f2383a426b34363e673c423a1d1d1d1d620453a363189j48',
#   'JOB': '餐飲服務生 / 調酒師／吧台人員',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '愛爾蘭咖啡坊',
#   'SAL_MONTH_HIGH': 33000.0,
#   'SAL_MONTH_LOW': 33000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 994.0,
#   'APPEAR_DATE': '20180105',
#   'J': '5e7447725e4a445a35363e6738323c1e14c3e462b5e604225252525213d552a29745j01',
#   'JOB': '**新開幕** 花月嵐 凱撒飯店--外場/內場 儲備幹部、正職人員',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '忠孝西路一段38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0462585,
#   'LON': 121.5164218,
#   'NAME': '晶旺餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 0.0,
#   'SAL_MONTH_LOW': 0.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 995.0,
#   'APPEAR_DATE': '20180105',
#   'J': '617346715d49435934353d6637313b1d04b3d452a5d5f4124242424693c642928654j49',
#   'JOB': '**新開幕** 花月嵐 凱撒飯店--外場/內場  工讀生、兼職人員、歡迎學生、二度就業',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段38號',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0462585,
#   'LON': 121.5164218,
#   'NAME': '晶旺餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 22400.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 996.0,
#   'APPEAR_DATE': '20180110',
#   'J': '553f482d63714e294937416849333b6423d3f4770393b436c41473f22222222642493f4f3634j53',
#   'JOB': '假日計時人員~北車站店(時薪140起)',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '忠孝西路一段36號B1(台北車站添好運樓下 交通便利)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0462371,
#   'LON': 121.5166359,
#   'NAME': '台灣吉豚屋餐飲股份有限公司',
#   'SAL_MONTH_HIGH': 24000.0,
#   'SAL_MONTH_LOW': 22400.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 997.0,
#   'APPEAR_DATE': '20180111',
#   'J': '6066492a604c465c373840693a443e2193e404a2f3a3c4627272727273f312c2b826j48',
#   'JOB': '★ 全新品牌★ 【神田日式食堂-中山捷運站】內場服務夥伴',
#   'JOBCAT_DESCRIPT': '日式廚師',
#   'JOB_ADDRESS': '中山區南京西路12巷1號(即將開幕，近捷運中山站2號出口)',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0520519,
#   'LON': 121.521496,
#   'NAME': '米塔集團:國際餐旅事業_二雪映月美食館',
#   'SAL_MONTH_HIGH': 39000.0,
#   'SAL_MONTH_LOW': 27000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 998.0,
#   'APPEAR_DATE': '20180110',
#   'J': '663e48285e4a445a35363e673c423b6424c74472b387043252525256a3d552a29745j54',
#   'JOB': '【台北車站】急徵!!知名日商集團定食料理餐廳誠徵外場正職人員 &學生實習',
#   'JOBCAT_DESCRIPT': '餐飲服務生',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '新加坡商艾得克有限公司台灣分公司',
#   'SAL_MONTH_HIGH': 35000.0,
#   'SAL_MONTH_LOW': 28000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  {'': 999.0,
#   'APPEAR_DATE': '20180110',
#   'J': '653d47275d49435934353d663b413a6314b73462a376f4224242424693c642928654j53',
#   'JOB': '【台北車站】急徵!!知名日商集團定食料理餐廳誠徵內場人員，無經驗、學生實習皆可',
#   'JOBCAT_DESCRIPT': '餐廚助手',
#   'JOB_ADDRESS': '',
#   'JOB_ADDR_NO_DESCRIPT': '台北市中正區',
#   'LAT': 25.0421407,
#   'LON': 121.5198716,
#   'NAME': '新加坡商艾得克有限公司台灣分公司',
#   'SAL_MONTH_HIGH': 34000.0,
#   'SAL_MONTH_LOW': 27000.0,
#   'bigadd': '台北市',
#   'smalladd': '中正區'},
#  ...]
